# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option("display.max_rows" ,500 )

# %%
dataset = pd.read_csv("groceries.csv")
dataset.head(3)
# Out:
#            Item 1  Item 2         Item 3        Item 4 Item 5 Item 6 Item 7  \
# 0  tropical fruit  yogurt         coffee           NaN    NaN    NaN    NaN
# 1      whole milk     NaN            NaN           NaN    NaN    NaN    NaN
# 2       pip fruit  yogurt  cream cheese   meat spreads    NaN    NaN    NaN
#
#   Item 8 Item 8.1 Item 9 Item 10  Item 11
# 0    NaN      NaN    NaN      NaN     NaN
# 1    NaN      NaN    NaN      NaN     NaN
# 2    NaN      NaN    NaN      NaN     NaN

# %%
dataset["Item 1"][0]
# Out:
# 'tropical fruit'

# %%
type(dataset['Item 4'][0])
# Out:
# float

# %%
dataset.shape
# Out:
# (9834, 12)

# %%
market =[]

for i in range(0,dataset.shape[0]):
    cus =[]
    for j in dataset.columns:
        if type(dataset[j][i])==str:
            cus.append(dataset[j][i])
    market.append(cus)

# %%
l =[]
for i in market: 
    for j in i: 
        l.append(j)

# %%
import collections

# %%
p =collections.Counter(l)

# %%
p.values()
# Out:
# dict_values([1032, 1369, 551, 2513, 744, 386, 40, 1903, 101, 328, 545, 66, 26, 1797, 329, 761, 75, 153, 52, 404, 1057, 433, 813, 523, 166, 165, 516, 580, 1664, 422, 320, 647, 734, 128, 247, 275, 864, 163, 163, 1072, 105, 87, 341, 343, 258, 23, 752, 924, 628, 895, 255, 327, 49, 279, 443, 567, 327, 703, 30, 220, 365, 67, 613, 109, 267, 239, 221, 256, 80, 164, 558, 163, 168, 261, 198, 74, 245, 466, 133, 124, 50, 182, 79, 32, 271, 79, 95, 54, 102, 270, 98, 305, 160, 184, 41, 88, 236, 141, 48, 100, 29, 43, 30, 75, 166, 14, 49, 63, 118, 28, 18, 83, 64, 20, 80, 19, 8, 42, 50, 87, 23, 254, 35, 108, 64, 28, 108, 90, 62, 42, 110, 8, 52, 62, 24, 11, 70, 97, 89, 7, 28, 50, 14, 28, 48, 6, 35, 29, 40, 48, 15, 12, 33, 9, 22, 13, 7, 16, 22, 23, 4, 8, 12, 4, 20, 1, 2, 2])

# %%
d = {"Item names":p.keys(), "Values":p.values() }

# %%
pd.DataFrame(d).sort_values(by=["Values"],ascending=False)
# Out:
#                     Item names  Values
# 3                   whole milk    2513
# 7             other vegetables    1903
# 13                  rolls/buns    1797
# 28                        soda    1664
# 1                       yogurt    1369
# 39             root vegetables    1072
# 20               bottled water    1057
# 0               tropical fruit    1032
# 47                     sausage     924
# 49               shopping bags     895
# 36                      pastry     864
# 22                citrus fruit     813
# 15                bottled beer     761
# 46                 canned beer     752
# 4                    pip fruit     744
# 32                  newspapers     734
# 57          whipped/sour cream     703
# 31       fruit/vegetable juice     647
# 48                 brown bread     628
# 62               domestic eggs     613
# 27                 frankfurter     580
# 55                        pork     567
# 70                   margarine     558
# 2                       coffee     551
# 10                      butter     545
# 23                        curd     523
# 26                        beef     516
# 77           frozen vegetables     466
# 54                     napkins     443
# 21                   chocolate     433
# 29                     chicken     422
# 19                 white bread     404
# 5                cream cheese      386
# 60                     dessert     365
# 43                     waffles     343
# 42                 salty snack     341
# 14                    UHT-milk     329
# 9     long life bakery product     328
# 51              hamburger meat     327
# 56                     berries     327
# 30                       sugar     320
# 91                      onions     305
# 53            hygiene articles     279
# 35                 butter milk     275
# 84         specialty chocolate     271
# 89                frozen meals     270
# 64             misc. beverages     267
# 73                         oil     261
# 44                       candy     258
# 67                         ham     256
# 50                   beverages     255
# 121                       meat     254
# 34               specialty bar     247
# 76                   ice cream     245
# 65                 hard cheese     239
# 96               sliced cheese     236
# 66                    cat food     221
# 59                      grapes     220
# 74                 chewing gum     198
# 93                  white wine     184
# 81              red/blush wine     182
# 72          pickled vegetables     168
# 24                       flour     166
# 104                soft cheese     166
# 25                      dishes     165
# 69         semi-finished bread     164
# 71               baking powder     163
# 37            processed cheese     163
# 38                   detergent     163
# 92                       herbs     160
# 17                  pot plants     153
# 97                       pasta     141
# 78                 canned fish     133
# 33   packaged fruit/vegetables     128
# 79           seasonal products     124
# 108                   cake bar     118
# 130                frozen fish     110
# 63               spread cheese     109
# 123                    mustard     108
# 126                     liquor     108
# 40              frozen dessert     105
# 88                        salt     102
# 8               condensed milk     101
# 99             cling film/bags     100
# 90           canned vegetables      98
# 137             roll products       97
# 86              flower (seeds)      95
# 127                   pet care      90
# 138                 mayonnaise      89
# 95                  photo/film      88
# 119               dish cleaner      87
# 41               sweet spreads      87
# 111           specialty cheese      83
# 68                      turkey      80
# 114                   dog food      80
# 85                     candles      79
# 82      frozen potato products      79
# 103      Instant food products      75
# 16          liquor (appetizer)      75
# 75       chocolate marshmallow      74
# 136             instant coffee      70
# 61                    zwieback      67
# 11                        rice      66
# 124     house keeping products      64
# 112          finished products      64
# 107                    popcorn      63
# 133                    vinegar      62
# 128                      soups      62
# 87              sparkling wine      54
# 18                     cereals      52
# 132                     sauces      52
# 118   female sanitary products      50
# 141                 liver loaf      50
# 80                 curd cheese      50
# 106                dental care      49
# 52                      spices      49
# 144             kitchen towels      48
# 149                        jam      48
# 98                    softener      48
# 101             male cosmetics      43
# 117                    cleaner      42
# 129                        rum      42
# 94                      brandy      41
# 148                    ketchup      40
# 6                 meat spreads      40
# 122                        tea      35
# 146                light bulbs      35
# 152                nuts/prunes      33
# 83               specialty fat      32
# 102               canned fruit      30
# 58            artif. sweetener      30
# 147                  skin care      29
# 100                       fish      29
# 140                      syrup      28
# 125            potato products      28
# 143                  nut snack      28
# 109             snack products      28
# 12            abrasive cleaner      26
# 134                       soap      24
# 159                    tidbits      23
# 45            bathroom cleaner      23
# 120                   cookware      23
# 154            organic sausage      22
# 158             pudding powder      22
# 113               cocoa drinks      20
# 164          cooking chocolate      20
# 115                   prosecco      19
# 110     flower soil/fertilizer      18
# 157       specialty vegetables      16
# 150                ready soups      15
# 142           organic products      14
# 105                      honey      14
# 155                      cream      13
# 151                decalcifier      12
# 162              frozen fruits      12
# 135                 hair spray      11
# 153                    liqueur       9
# 161                     whisky       8
# 116            make up remover       8
# 131             salad dressing       8
# 139            rubbing alcohol       7
# 156             toilet cleaner       7
# 145             frozen chicken       6
# 160             baby cosmetics       4
# 163                       bags       4
# 166            kitchen utensil       2
# 167      preservation products       2
# 165       sound storage medium       1

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr =TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market) ,columns=tr.columns_)

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(df ,min_support=0.07 ,use_colnames=True ,max_len=3).sort_values(by=["support"])
# Out:
#      support                        itemsets
# 16  0.071487            (whipped/sour cream)
# 10  0.074639                    (newspapers)
# 17  0.074842  (other vegetables, whole milk)
# 3   0.075656                     (pip fruit)
# 13  0.076469                   (canned beer)
# 6   0.077385                  (bottled beer)
# 8   0.082672                  (citrus fruit)
# 11  0.087858                        (pastry)
# 15  0.091011                 (shopping bags)
# 14  0.093960                       (sausage)
# 1   0.104942                (tropical fruit)
# 7   0.107484                 (bottled water)
# 12  0.109010               (root vegetables)
# 0   0.139211                        (yogurt)
# 9   0.169209                          (soda)
# 5   0.182733                    (rolls/buns)
# 4   0.193512              (other vegetables)
# 2   0.255542                    (whole milk)
